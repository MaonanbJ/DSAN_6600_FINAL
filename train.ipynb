# %%
import sys
import os
import tensorflow as tf
from tensorflow.keras.optimizers import Adam
from tensorflow.keras.losses import CategoricalCrossentropy
from tensorflow.keras.metrics import Mean, CategoricalAccuracy
from tensorflow.keras.callbacks import EarlyStopping, ModelCheckpoint
import matplotlib.pyplot as plt

# Ensure the correct path
sys.path.append(os.getcwd())

# Import your model architecture and data reading function
from model.ResNet34 import resnet34
from detection.bin.cnndetection import read_data

# Set training parameters
im_height = 224
im_width = 224
num_classes = 4  # Update this with the actual number of classes
batch_size = 16
epochs = 50

# Load and process the data
X_train, X_val, X_test, Y_train, Y_val, Y_test = read_data()
#X_train, X_val, Y_train, Y_val = read_data()

# Create the ResNet34 model
model = resnet34(im_width=im_width, im_height=im_height, num_classes=num_classes,weight_decay=1e-4)

# Compile the model
model.compile(optimizer=Adam(learning_rate=0.0002),
              loss=CategoricalCrossentropy(from_logits=False),
              metrics=[CategoricalAccuracy()])

callbacks = [
    EarlyStopping(monitor='val_loss', patience=5, verbose=1),
    ModelCheckpoint(filepath='./save_weights/resNet_34.ckpt', save_best_only=True, monitor='val_loss', verbose=1)
]

# Train the model
history = model.fit(
    x=X_train, 
    y=Y_train, 
    batch_size=batch_size, 
    epochs=epochs, 
    validation_data=(X_val, Y_val),
    callbacks=callbacks
)

# Evaluate the model on the test dataset
test_loss, test_accuracy = model.evaluate(X_test, Y_test, batch_size=batch_size)
print(f'Final Test Loss: {test_loss}, Test Accuracy: {test_accuracy * 100}')
# Out:
# Category labels: {'Mild Dementia': 0, 'Moderate Dementia': 1, 'Non Demented': 2, 'Very mild Dementia': 3}
# Processing Mild Dementia...
# Processing Moderate Dementia...
# Processing Non Demented...
# Processing Very mild Dementia...
# Category labels: {'Mild Dementia': 0, 'Moderate Dementia': 1, 'Non Demented': 2, 'Very mild Dementia': 3}
# Processing Mild Dementia...
# Processing Moderate Dementia...
# Processing Non Demented...
# Processing Very mild Dementia...
# Training data shape: (2816, 224, 224, 3)
# Validation data shape: (704, 224, 224, 3)
# Testing data shape: (1248, 224, 224, 3)
# Training labels shape: (2816, 4)
# Validation labels shape: (704, 4)
# Testing labels shape: (1248, 4)
# Epoch 1/50
# 176/176 [==============================] - 23s 74ms/step - loss: 1.2468 - categorical_accuracy: 0.6587 - val_loss: 1.2661 - val_categorical_accuracy: 0.6420
#
# Epoch 00001: val_loss improved from inf to 1.26613, saving model to ./save_weights\resNet_34.ckpt
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, conv2d_1_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses while saving (showing 5 of 320). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# c:\Users\z7567\.conda\envs\dsan6600-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 2/50
# 176/176 [==============================] - 13s 71ms/step - loss: 0.8486 - categorical_accuracy: 0.8299 - val_loss: 2.0500 - val_categorical_accuracy: 0.6449
#
# Epoch 00002: val_loss did not improve from 1.26613
# Epoch 3/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.7189 - categorical_accuracy: 0.8874 - val_loss: 0.8738 - val_categorical_accuracy: 0.8423
#
# Epoch 00003: val_loss improved from 1.26613 to 0.87376, saving model to ./save_weights\resNet_34.ckpt
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, conv2d_1_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses while saving (showing 5 of 320). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# c:\Users\z7567\.conda\envs\dsan6600-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 4/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.6187 - categorical_accuracy: 0.9197 - val_loss: 0.9319 - val_categorical_accuracy: 0.8040
#
# Epoch 00004: val_loss did not improve from 0.87376
# Epoch 5/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.5873 - categorical_accuracy: 0.9311 - val_loss: 1.2922 - val_categorical_accuracy: 0.7528
#
# Epoch 00005: val_loss did not improve from 0.87376
# Epoch 6/50
# 176/176 [==============================] - 13s 75ms/step - loss: 0.5471 - categorical_accuracy: 0.9485 - val_loss: 0.7627 - val_categorical_accuracy: 0.8750
#
# Epoch 00006: val_loss improved from 0.87376 to 0.76270, saving model to ./save_weights\resNet_34.ckpt
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, conv2d_1_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses while saving (showing 5 of 320). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# c:\Users\z7567\.conda\envs\dsan6600-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 7/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.5368 - categorical_accuracy: 0.9485 - val_loss: 0.8380 - val_categorical_accuracy: 0.8750
#
# Epoch 00007: val_loss did not improve from 0.76270
# Epoch 8/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.4878 - categorical_accuracy: 0.9688 - val_loss: 0.7010 - val_categorical_accuracy: 0.9062
#
# Epoch 00008: val_loss improved from 0.76270 to 0.70099, saving model to ./save_weights\resNet_34.ckpt
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, conv2d_1_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses while saving (showing 5 of 320). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# c:\Users\z7567\.conda\envs\dsan6600-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 9/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4887 - categorical_accuracy: 0.9659 - val_loss: 0.7970 - val_categorical_accuracy: 0.9091
#
# Epoch 00009: val_loss did not improve from 0.70099
# Epoch 10/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4413 - categorical_accuracy: 0.9801 - val_loss: 0.7817 - val_categorical_accuracy: 0.8963
#
# Epoch 00010: val_loss did not improve from 0.70099
# Epoch 11/50
# 176/176 [==============================] - 13s 72ms/step - loss: 0.4381 - categorical_accuracy: 0.9794 - val_loss: 0.6515 - val_categorical_accuracy: 0.9190
#
# Epoch 00011: val_loss improved from 0.70099 to 0.65154, saving model to ./save_weights\resNet_34.ckpt
# WARNING:absl:Found untraced functions such as conv2d_layer_call_and_return_conditional_losses, conv2d_layer_call_fn, conv2d_1_layer_call_and_return_conditional_losses, conv2d_1_layer_call_fn, re_lu_1_layer_call_and_return_conditional_losses while saving (showing 5 of 320). These functions will not be directly callable after loading.
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# INFO:tensorflow:Assets written to: ./save_weights\resNet_34.ckpt\assets
# c:\Users\z7567\.conda\envs\dsan6600-gpu\lib\site-packages\keras\utils\generic_utils.py:494: CustomMaskWarning: Custom mask layers require a config and must override get_config. When loading, the custom mask layer must be passed to the custom_objects argument.
#   warnings.warn('Custom mask layers require a config and must override '
# Epoch 12/50
# 176/176 [==============================] - 13s 73ms/step - loss: 0.4448 - categorical_accuracy: 0.9734 - val_loss: 0.8240 - val_categorical_accuracy: 0.8878
#
# Epoch 00012: val_loss did not improve from 0.65154
# Epoch 13/50
# 176/176 [==============================] - 13s 74ms/step - loss: 0.4358 - categorical_accuracy: 0.9748 - val_loss: 0.7986 - val_categorical_accuracy: 0.8835
#
# Epoch 00013: val_loss did not improve from 0.65154
# Epoch 14/50
# 176/176 [==============================] - 15s 84ms/step - loss: 0.4352 - categorical_accuracy: 0.9719 - val_loss: 0.7566 - val_categorical_accuracy: 0.8906
#
# Epoch 00014: val_loss did not improve from 0.65154
# Epoch 15/50
# 176/176 [==============================] - 13s 75ms/step - loss: 0.3846 - categorical_accuracy: 0.9908 - val_loss: 0.7290 - val_categorical_accuracy: 0.9219
#
# Epoch 00015: val_loss did not improve from 0.65154
# Epoch 16/50
# 176/176 [==============================] - 13s 76ms/step - loss: 0.4030 - categorical_accuracy: 0.9805 - val_loss: 0.7714 - val_categorical_accuracy: 0.9077
#
# Epoch 00016: val_loss did not improve from 0.65154
# Epoch 00016: early stopping
# 78/78 [==============================] - 2s 24ms/step - loss: 0.8777 - categorical_accuracy: 0.8630
# Final Test Loss: 0.8777011036872864, Test Accuracy: 86.29807829856873

# %%
plt.plot(history.history['loss'], label='train')
plt.plot(history.history['val_loss'], label='validation')
plt.xlabel('Epoch')
plt.ylabel('Loss')
plt.legend()
plt.show()
#plt.savefig('loss.png')
plt.plot(history.history['categorical_accuracy'], label='train')
plt.plot(history.history['val_categorical_accuracy'], label='validation')
plt.xlabel('Epoch')
plt.ylabel('Accuracy')
plt.legend()
plt.savefig('accuracy.png')
#plt.show()
